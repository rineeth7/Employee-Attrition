# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("/content/drive/MyDrive/Brute Force/general_data.csv")

# %%
df
# Out:
#       Age Attrition  ... YearsSinceLastPromotion YearsWithCurrManager
# 0      51        No  ...                       0                    0
# 1      31       Yes  ...                       1                    4
# 2      32        No  ...                       0                    3
# 3      38        No  ...                       7                    5
# 4      32        No  ...                       0                    4
# ...   ...       ...  ...                     ...                  ...
# 4405   42        No  ...                       0                    2
# 4406   29        No  ...                       0                    2
# 4407   25        No  ...                       1                    2
# 4408   42        No  ...                       7                    8
# 4409   40        No  ...                       3                    9
#
# [4410 rows x 24 columns]

# %%
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeID                  0
# Gender                      0
# JobLevel                    0
# JobRole                     0
# MaritalStatus               0
# MonthlyIncome               0
# NumCompaniesWorked         19
# Over18                      0
# PercentSalaryHike           0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           9
# TrainingTimesLastYear       0
# YearsAtCompany              0
# YearsSinceLastPromotion     0
# YearsWithCurrManager        0
# dtype: int64

# %%
df=df.dropna()

# %%
df.isnull().sum()
# Out:
# Age                        0
# Attrition                  0
# BusinessTravel             0
# Department                 0
# DistanceFromHome           0
# Education                  0
# EducationField             0
# EmployeeCount              0
# EmployeeID                 0
# Gender                     0
# JobLevel                   0
# JobRole                    0
# MaritalStatus              0
# MonthlyIncome              0
# NumCompaniesWorked         0
# Over18                     0
# PercentSalaryHike          0
# StandardHours              0
# StockOptionLevel           0
# TotalWorkingYears          0
# TrainingTimesLastYear      0
# YearsAtCompany             0
# YearsSinceLastPromotion    0
# YearsWithCurrManager       0
# dtype: int64

# %%
df.describe()
# Out:
#                Age  ...  YearsWithCurrManager
# count  4382.000000  ...           4382.000000
# mean     36.933364  ...              4.126198
# std       9.137272  ...              3.569674
# min      18.000000  ...              0.000000
# 25%      30.000000  ...              2.000000
# 50%      36.000000  ...              3.000000
# 75%      43.000000  ...              7.000000
# max      60.000000  ...             17.000000
#
# [8 rows x 16 columns]

# %%
# Delete Unwanted Records since it has nothing to do with the attrition of the employees
#  This features aren't useful for us, So we are going to drop those columns
df.drop(labels=['EmployeeCount','EmployeeID','Over18','StandardHours','StockOptionLevel','Education'],axis='columns',inplace=True)
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py:4174: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df
# Out:
#       Age Attrition  ... YearsSinceLastPromotion YearsWithCurrManager
# 0      51        No  ...                       0                    0
# 1      31       Yes  ...                       1                    4
# 2      32        No  ...                       0                    3
# 3      38        No  ...                       7                    5
# 4      32        No  ...                       0                    4
# ...   ...       ...  ...                     ...                  ...
# 4404   29        No  ...                       1                    5
# 4405   42        No  ...                       0                    2
# 4406   29        No  ...                       0                    2
# 4407   25        No  ...                       1                    2
# 4408   42        No  ...                       7                    8
#
# [4382 rows x 18 columns]

# %%
df.Attrition[df.Attrition=='Yes'] = 1
df.Attrition[df.Attrition=='No'] = 0
df['Attrition'] = df['Attrition'].astype(int)
df['NumCompaniesWorked'] = df['NumCompaniesWorked'].astype(int)
df['TotalWorkingYears'] = df['TotalWorkingYears'].astype(int)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/series.py:1020: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# ...

# %%
df
# Out:
#       Age  Attrition  ... YearsSinceLastPromotion YearsWithCurrManager
# 0      51          0  ...                       0                    0
# 1      31          1  ...                       1                    4
# 2      32          0  ...                       0                    3
# 3      38          0  ...                       7                    5
# 4      32          0  ...                       0                    4
# ...   ...        ...  ...                     ...                  ...
# 4404   29          0  ...                       1                    5
# 4405   42          0  ...                       0                    2
# 4406   29          0  ...                       0                    2
# 4407   25          0  ...                       1                    2
# 4408   42          0  ...                       7                    8
#
# [4382 rows x 18 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4382 entries, 0 to 4408
# Data columns (total 18 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      4382 non-null   int64
#  1   Attrition                4382 non-null   int64
#  2   BusinessTravel           4382 non-null   object
#  3   Department               4382 non-null   object
#  4   DistanceFromHome         4382 non-null   int64
#  5   EducationField           4382 non-null   object
#  6   Gender                   4382 non-null   object
#  7   JobLevel                 4382 non-null   int64
#  8   JobRole                  4382 non-null   object
#  9   MaritalStatus            4382 non-null   object
#  10  MonthlyIncome            4382 non-null   int64
#  11  NumCompaniesWorked       4382 non-null   int64
#  12  PercentSalaryHike        4382 non-null   int64
#  13  TotalWorkingYears        4382 non-null   int64
# ...

# %%
#Correlation of each column on attrition.
df.drop('Attrition', axis=1).corrwith(df.Attrition).plot(kind='barh', figsize=(10, 7))

# %%
plt.figure(figsize=(30, 30))
sns.heatmap(df.corr(), annot=True, cmap="RdYlGn", annot_kws={"size":13})

# %%
data= df[["Attrition","Age","DistanceFromHome","MonthlyIncome","PercentSalaryHike","YearsAtCompany"]].copy()
plt.figure(figsize=(30, 30))
sns.heatmap(data.corr(), annot=True, cmap="RdYlGn", annot_kws={"size":13})

# %%
fig=plt.figure(figsize=(15,4))
ax=sns.kdeplot(df.loc[(df['Attrition']==0),'YearsAtCompany'],color='g',shade=False,label='No Attrition')
ax=sns.kdeplot(df.loc[(df['Attrition']==1),'YearsAtCompany'],color='r',shade=True,label='Attrition')
ax.set(xlabel='Employee YearsAtCompany ',ylabel='Frequency')
plt.title('Employee YearsAtCompany - Attrition vs No Attrition')
# Out:
# Text(0.5, 1.0, 'Employee YearsAtCompany - Attrition vs No Attrition')

# %%
df['Income_Range']=pd.cut(df['MonthlyIncome'],[1000,5000,10000,15000,20000])
f, ax = plt.subplots(figsize=(15, 4))
sns.countplot(y='Income_Range',hue='Attrition',data=df).set_title('Employee Salary Attrition Distribution')
plt.plot()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# []

# %%
if isinstance(df, (pd.DatetimeIndex, pd.MultiIndex)):
	df = df.to_frame(index=False)

# remove any pre-existing indices for ease of use in the D-Tale code, but this is not required
df = df.reset_index().drop('index', axis=1, errors='ignore')
df.columns = [str(c) for c in df.columns]  # update columns to strings in case they are numbers

chart_data = pd.concat([
	df['Age'],
	df['Attrition'],
], axis=1)
chart_data = chart_data.sort_values(['Age'])
chart_data = chart_data.rename(columns={'Age': 'x'})
chart_data = chart_data.groupby(['x'])[['Attrition']].count().reset_index()
chart_data = chart_data.dropna()

import plotly.graph_objs as go

charts = []
line_cfg = {'line': {'shape': 'spline', 'smoothing': 0.3}, 'mode': 'lines'}
charts.append(go.Scatter(
	x=chart_data['x'], y=chart_data['Attrition'], name='Attrition', **line_cfg
))
figure = go.Figure(data=charts, layout=go.Layout({
    'legend': {'orientation': 'h'},
    'title': {'text': 'Attrition by Age'},
    'xaxis': {'tickformat': '.0f', 'title': {'text': 'Age'}},
    'yaxis': {'title': {'text': 'Attrition'}}
}))
figure
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="861124e0-2f6e-497a-b0d4-4332e0ed6af1" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("861124e0-2f6e-497a-b0d4-4332e0ed6af1")) {
#                     Plotly.newPlot(
#                         '861124e0-2f6e-497a-b0d4-4332e0ed6af1',
# ...

# %%
sns.barplot(x='Attrition',y='DistanceFromHome',hue='Gender',data=df,palette='icefire').set_title('Effect of distance of home for different gender')
plt.show()

# %%
fig=plt.figure(figsize=(10,6))
sns.countplot(x='YearsSinceLastPromotion',hue='Attrition',data=df,palette="inferno")
plt.show()

# %%
total_records= len(df)
columns = ["Gender","MaritalStatus","PercentSalaryHike", 
           'NumCompaniesWorked',"BusinessTravel",'Department']

j=0
for i in columns:
    j +=1
    plt.subplot(5,2,j)
    ax1 = sns.countplot(data=df,x= i,hue="Attrition")
    if(j==9 or j== 10):
        plt.xticks( rotation=90)
        
# Custom the subplot layout
plt.subplots_adjust(bottom=0.1, top=4)
plt.show()

# %%
df.drop(['Income_Range'],axis=1)
# Out:
#       Age  Attrition  ... YearsSinceLastPromotion YearsWithCurrManager
# 0      51          0  ...                       0                    0
# 1      31          1  ...                       1                    4
# 2      32          0  ...                       0                    3
# 3      38          0  ...                       7                    5
# 4      32          0  ...                       0                    4
# ...   ...        ...  ...                     ...                  ...
# 4377   29          0  ...                       1                    5
# 4378   42          0  ...                       0                    2
# 4379   29          0  ...                       0                    2
# 4380   25          0  ...                       1                    2
# 4381   42          0  ...                       7                    8
#
# [4382 rows x 18 columns]

# %%
fig=plt.figure(figsize=(10,6))
sns.countplot(x='PercentSalaryHike',hue='Attrition',data=df,palette="Reds")
plt.show()

# %%
df
# Out:
#       Age  Attrition  ... YearsWithCurrManager Income_Range
# 0      51          0  ...                    0          NaN
# 1      31          1  ...                    4          NaN
# 2      32          0  ...                    3          NaN
# 3      38          0  ...                    5          NaN
# 4      32          0  ...                    4          NaN
# ...   ...        ...  ...                  ...          ...
# 4377   29          0  ...                    5          NaN
# 4378   42          0  ...                    2          NaN
# 4379   29          0  ...                    2          NaN
# 4380   25          0  ...                    2          NaN
# 4381   42          0  ...                    8          NaN
#
# [4382 rows x 19 columns]

# %%
data=df.select_dtypes(np.number)
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

X = data.drop('Attrition', axis=1)
y = data.Attrition

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42,
                                                    stratify=y)

scaler = StandardScaler()
X_train_std = scaler.fit_transform(X_train)
X_test_std = scaler.transform(X_test)
X_std = scaler.transform(X)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score, f1_score

def print_score(clf, X_train, y_train, X_test, y_test, train=True):
    if train==False:
        pred = clf.predict(X_test)
        print("Test Result:\n================================================")        
        print(f"Accuracy Score: {accuracy_score(y_test, pred) * 100:.2f}%")
        print("_______________________________________________")
        print("Classification Report:", end='')
        print(f"\tPrecision Score: {precision_score(y_test, pred) * 100:.2f}%")
        print(f"\t\t\tRecall Score: {recall_score(y_test, pred) * 100:.2f}%")
        print(f"\t\t\tF1 score: {f1_score(y_test, pred) * 100:.2f}%")
        print("_______________________________________________")
        print(f"Confusion Matrix: \n {confusion_matrix(y_test, pred)}\n")

# %%
from sklearn.linear_model import LogisticRegression

lr_classifier = LogisticRegression(solver='liblinear', penalty='l1')
lr_classifier.fit(X_train_std, y_train)

print_score(lr_classifier, X_train_std, y_train, X_test_std, y_test, train=True)
print_score(lr_classifier, X_train_std, y_train, X_test_std, y_test, train=False)
# Out:
# Test Result:
# ...
# Accuracy Score: 83.95%
# _______________________________________________
# Classification Report:	Precision Score: 100.00%
# 			Recall Score: 0.47%
# 			F1 score: 0.94%
# _______________________________________________
# Confusion Matrix:
#  [[1103    0]
#  [ 211    1]]

# %%
from sklearn.ensemble import RandomForestClassifier

rand_forest = RandomForestClassifier(n_estimators=1200, 
                                    )
rand_forest.fit(X_train, y_train)

print_score(rand_forest, X_train, y_train, X_test, y_test, train=True)
print_score(rand_forest, X_train, y_train, X_test, y_test, train=False)
# Out:
# Test Result:
# ...
# Accuracy Score: 98.17%
# _______________________________________________
# Classification Report:	Precision Score: 100.00%
# 			Recall Score: 88.68%
# 			F1 score: 94.00%
# _______________________________________________
# Confusion Matrix:
#  [[1103    0]
#  [  24  188]]
